# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data and Change File Type
#
# - 3/6/2023: Importing the data from [NYC Open Data](https://data.cityofnewyork.us/City-Government/NYC-Jobs/pda4-rgn4/) as a CSV file.
# - Transform file from CSV to parquet to compress file size

# %%
df_parquet = pd.read_parquet(r'data/nyc_jobs.parquet')

# %%
df_parquet.head(3)
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0  541356         BRONX DISTRICT ATTORNEY     Internal               6
# 1  571700  DEPT OF ENVIRONMENT PROTECTION     External               1
# 2  573919  HOUSING PRESERVATION & DVLPMNT     Internal               1
#
#                                       Business Title  \
# 0                        Senior Rackets Investigator
# 1                                ACCOUNTABLE MANAGER
# 2  Case Manager for the Division of Tenant Resources
#
#            Civil Service Title Title Code No Level  Salary Range From  \
# 0  SENIOR RACKETS INVESTIGATOR         30831    00            70877.0
# 1       ENVIRONMENTAL ENGINEER         20618    02            80557.0
# 2          COMMUNITY ASSOCIATE         56057    00            38333.0
#
#    Salary Range To  ...                                    Job Description  \
# 0          70877.0  ...  The Bronx District Attorneyâs Office is seek...
# ...

# %%
###

# %%
df_parquet.columns
# Out:
# Index(['Job ID', 'Agency', 'Posting Type', '# Of Positions', 'Business Title',
#        'Civil Service Title', 'Title Code No', 'Level', 'Salary Range From',
#        'Salary Range To', 'Salary Frequency', 'Work Location',
#        'Division/Work Unit', 'Job Description', 'Minimum Qual Requirements',
#        'Preferred Skills', 'Additional Information', 'To Apply', 'Hours/Shift',
#        'Work Location 1', 'Recruitment Contact', 'Residency Requirement',
#        'Post Until'],
#       dtype='object')

# %%
cols_to_keep = [1,4,8,9,10,13,14,15,16]

df_jobs = df_parquet.iloc[:, cols_to_keep]
df_jobs.head(3)
# Out:
#                            Agency  \
# 0         BRONX DISTRICT ATTORNEY
# 1  DEPT OF ENVIRONMENT PROTECTION
# 2  HOUSING PRESERVATION & DVLPMNT
#
#                                       Business Title  Salary Range From  \
# 0                        Senior Rackets Investigator            70877.0
# 1                                ACCOUNTABLE MANAGER            80557.0
# 2  Case Manager for the Division of Tenant Resources            38333.0
#
#    Salary Range To Salary Frequency  \
# 0          70877.0           Annual
# 1         111917.0           Annual
# 2          44083.0           Annual
#
#                                      Job Description  \
# 0  The Bronx District Attorneyâs Office is seek...
# 1  The NYC Department of Environmental Protection...
# 2  About the Agency:   The NYC Department Housing...
#
#                            Minimum Qual Requirements  \
# 0  1. Graduation from high school or its equivale...
# 1  1. A valid New York State Professional Enginee...
# ...
