# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import requests
from zipfile import ZipFile
from IPython.display import Markdown

# download zip file
url = 'https://www.cs.ucsb.edu/~william/data/liar_dataset.zip'

request = requests.get(url)
with open('data/liar_dataset.zip', 'wb') as fd:
    fd.write(request.content)

# unzip and see what's inside
zf = ZipFile('data/liar_dataset.zip')
zf.extractall(path = 'data')
zf.close()
zf.namelist()

# define list of column names
columns = [
    'id',
    'label',
    'statement',
    'subjects',
    'speaker',
    'speaker_job',
    'state',
    'party', 
    'barely_true',
    'false',
    'half_true',
    'mostly_true',
    'pants_on_fire',
    'context'
]

# loop through each file and read in as a pandas dataframe
files = ['test', 'train', 'valid']

for file in files:
    filename = 'data/' + file + '.tsv'
    globals()[file] = pd.read_csv(filename, sep = '\t', names = columns)
    os.remove(filename)
    
    print(f'{file} - No. observations: {len(globals()[file])}')

# delete the zip files to keep our directory clean
os.remove('data/liar_dataset.zip')

statements_per_speaker = train.speaker.value_counts()
statements_per_speaker = statements_per_speaker[statements_per_speaker > 10]

statements_per_speaker.head(10)
# Out:
# test - No. observations: 1267
# train - No. observations: 10240
# valid - No. observations: 1284
# barack-obama       488
# donald-trump       273
# hillary-clinton    239
# mitt-romney        176
# scott-walker       149
# john-mccain        148
# rick-perry         142
# chain-email        142
# marco-rubio        117
# rick-scott         115
# Name: speaker, dtype: int64

# %%
sns.histplot(data = statements_per_speaker, bins = 40, stat = 'density')
plt.show()

# %%
sns.histplot(data = statements_per_speaker.dropna(), bins = 40, stat = 'density')
plt.show()

# %%
sns.histplot(data = statements_per_speaker.dropna(), bins = 40, stat = 'density', color = 'red')
plt.show()

# %%
df = pd.DataFrame({
    'feature1': np.random.randn(100),
    'feature2': np.random.rand(100),
    'feature3': np.random.randn(100) / 2,
    'feature4': np.random.rand(100) * 2
})

sns.scatterplot(x = 'feature1', y = 'feature2', data = df)
# Out:
# <AxesSubplot:xlabel='feature1', ylabel='feature2'>

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', linewidths = 0.5)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', linewidths = 0.5)
plt.show()
